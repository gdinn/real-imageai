# %%
import numpy as np
import matplotlib.pyplot as plt

## Precision graph. Values obtained from the models/accuracy.json file obtained on the accuracy script.

precision = [
    0.006673169567101282,
    0.032133079392751736,
    0.5295020628128274,
    0.5644786312380169,
    0.6397352493306695,
    0.5864579699520449,
    0.6250105532674022,
    0.5314856198122215,
    0.674630903264607,
    0.8097740605654382,
    0.6981011200271396,
    0.7351306222097358,
    0.5736816292858931,
    0.788251785784539,
    0.7611032542663769,
    0.7887702181890464,
    0.6623990646059872,
    0.6282401930965729,
    0.8408633516027737,
    0.8796849780152971,
    0.8329084702521732,
    0.8299564817192642,
    0.787072923456311,
    0.7491663694982535,
    0.8118750484916264,
    0.777286133890944    
]


fig, ax = plt.subplots(1, 1, figsize=(16, 8))
ax.grid(which='both', axis='both')
x = np.arange(1,len(precision)+1,1)
ax.set_title("Precision VS No. of epochs")
ax.set_xlabel("No. of epochs")
ax.set_ylabel("Precision")
ax.set_xticks(x)
ax.plot(x,precision)
